# %%
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
num1 = random.randint(100,500)
num1
# Out:
# 271

# %%
for i in range(20):
    num1 = random.randint(100,500)
    num2 = random.randint(1000,5000)
    num3 = random.randint(10000,50000)
    #print(num1)
    #print(num2)
    #print(num3)

# %%
    dataset = pd.DataFrame({
        "Number1": [274,225,474,317,241,135,448,362,290,266,235,412,246,463,451,337,370,216,318,320],
        "Number2": [4397,2328,4361,1828,3109,1294,3575,4980,2163,3741,3199,4946,3430,3582,4416,2144,3081,4668,3068,3918],
        "Number3": [16854,17234,16919,26161,21490,16152,19931,14494,47934,20270,21404,38671,10346,42334,43497,36610,33456,46216,16279,11466],
    })

# %%
dataset
# Out:
#     Number1  Number2  Number3
# 0       274     4397    16854
# 1       225     2328    17234
# 2       474     4361    16919
# 3       317     1828    26161
# 4       241     3109    21490
# 5       135     1294    16152
# 6       448     3575    19931
# 7       362     4980    14494
# 8       290     2163    47934
# 9       266     3741    20270
# 10      235     3199    21404
# 11      412     4946    38671
# 12      246     3430    10346
# 13      463     3582    42334
# 14      451     4416    43497
# 15      337     2144    36610
# 16      370     3081    33456
# 17      216     4668    46216
# 18      318     3068    16279
# 19      320     3918    11466

# %%
sns.distplot(dataset["Number3"])
plt.show()
# Out:
# C:\Users\ashvi\AppData\Local\Temp\ipykernel_14964\2368967815.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Number3"])

# %%
dataset.describe()
# Out:
#           Number1      Number2       Number3
# count   20.000000    20.000000     20.000000
# mean   320.000000  3411.400000  25885.900000
# std     94.501462  1061.060959  12408.517579
# min    135.000000  1294.000000  10346.000000
# 25%    244.750000  2883.000000  16710.250000
# 50%    317.500000  3502.500000  20837.000000
# 75%    380.500000  4370.000000  37125.250000
# max    474.000000  4980.000000  47934.000000

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
ss.fit(dataset[["Number3"]])
# Out:
# StandardScaler()

# %%
ss.transform(dataset[["Number3"]])
# Out:
# array([[-0.74678815],
#        [-0.71536846],
#        [-0.74141373],
#        [ 0.0227462 ],
#        [-0.36346793],
#        [-0.80483189],
#        [-0.49237134],
#        [-0.94192096],
#        [ 1.82301175],
#        [-0.46434167],
#        [-0.37057871],
#        [ 1.05711546],
#        [-1.28489168],
#        [ 1.35998474],
#        [ 1.45614553],
#        [ 0.88670499],
#        [ 0.62592156],
#        [ 1.68096168],
#        [-0.7943311 ],
#        [-1.19228628]])

# %%
dataset["Number3_scaled"] = ss.transform(dataset[["Number3"]])

# %%
dataset
# Out:
#     Number1  Number2  Number3  Number3_scaled
# 0       274     4397    16854       -0.746788
# 1       225     2328    17234       -0.715368
# 2       474     4361    16919       -0.741414
# 3       317     1828    26161        0.022746
# 4       241     3109    21490       -0.363468
# 5       135     1294    16152       -0.804832
# 6       448     3575    19931       -0.492371
# 7       362     4980    14494       -0.941921
# 8       290     2163    47934        1.823012
# 9       266     3741    20270       -0.464342
# 10      235     3199    21404       -0.370579
# 11      412     4946    38671        1.057115
# 12      246     3430    10346       -1.284892
# 13      463     3582    42334        1.359985
# 14      451     4416    43497        1.456146
# 15      337     2144    36610        0.886705
# 16      370     3081    33456        0.625922
# 17      216     4668    46216        1.680962
# 18      318     3068    16279       -0.794331
# ...

# %%
dataset.describe()
# Out:
#           Number1      Number2       Number3  Number3_scaled
# count   20.000000    20.000000     20.000000    2.000000e+01
# mean   320.000000  3411.400000  25885.900000   -9.992007e-17
# std     94.501462  1061.060959  12408.517579    1.025978e+00
# min    135.000000  1294.000000  10346.000000   -1.284892e+00
# 25%    244.750000  2883.000000  16710.250000   -7.586739e-01
# 50%    317.500000  3502.500000  20837.000000   -4.174602e-01
# 75%    380.500000  4370.000000  37125.250000    9.293076e-01
# max    474.000000  4980.000000  47934.000000    1.823012e+00

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ms = MinMaxScaler()

# %%
ms.fit(dataset[["Number2"]])
# Out:
# MinMaxScaler()

# %%
ms.transform(dataset[["Number2"]])
# Out:
# array([[0.84183397],
#        [0.28052089],
#        [0.83206728],
#        [0.14487249],
#        [0.49240369],
#        [0.        ],
#        [0.618828  ],
#        [1.        ],
#        [0.23575692],
#        [0.66386327],
#        [0.5168204 ],
#        [0.99077591],
#        [0.57948996],
#        [0.62072708],
#        [0.84698861],
#        [0.23060228],
#        [0.48480738],
#        [0.9153554 ],
#        [0.48128052],
#        [0.7118828 ]])

# %%
dataset["Number2_scaled"] = ms.transform(dataset[["Number2"]])
dataset
# Out:
#     Number1  Number2  Number3  Number3_scaled  Number2_scaled
# 0       274     4397    16854       -0.746788        0.841834
# 1       225     2328    17234       -0.715368        0.280521
# 2       474     4361    16919       -0.741414        0.832067
# 3       317     1828    26161        0.022746        0.144872
# 4       241     3109    21490       -0.363468        0.492404
# 5       135     1294    16152       -0.804832        0.000000
# 6       448     3575    19931       -0.492371        0.618828
# 7       362     4980    14494       -0.941921        1.000000
# 8       290     2163    47934        1.823012        0.235757
# 9       266     3741    20270       -0.464342        0.663863
# 10      235     3199    21404       -0.370579        0.516820
# 11      412     4946    38671        1.057115        0.990776
# 12      246     3430    10346       -1.284892        0.579490
# 13      463     3582    42334        1.359985        0.620727
# ...
