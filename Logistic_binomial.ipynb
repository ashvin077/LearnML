# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel("C:/ML Course/Datasets/logistic.xlsx")
dataset.drop(columns={"salary"},inplace=True)
dataset
# Out:
#     age  purchase
# 0    20         1
# 1    37         1
# 2    47         1
# 3    24         0
# 4    21         1
# ..  ...       ...
# 95   25         0
# 96   25         1
# 97   25         0
# 98   35         1
# 99   34         0
#
# [100 rows x 2 columns]

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="age", y="purchase",data=dataset)
plt.show()

# %%
x = dataset[["age"]]
y = dataset["purchase"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train, y_train)*100
# Out:
# 57.49999999999999

# %%
lr.predict([[30]])
# Out:
# C:\python1\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
sns.scatterplot(x="age",y="purchase",data = dataset)
sns.lineplot(x="age",y=lr.predict(x),data=dataset,color='red')
plt.show()
