# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel("C:/ML Course/Datasets/logistic.xlsx")
dataset.head(5)
# Out:
#    age  salary  purchase
# 0   20  107580         1
# 1   37   61291         1
# 2   47   83240         1
# 3   24   71021         0
# 4   21   63307         1

# %%
sns.scatterplot(x="age",y="salary",data=dataset,hue="purchase")
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["purchase"]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=3)
pf.fit(x)
x = pd.DataFrame(pf.transform(x))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3,random_state=46)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.6

# %%
lr.predict([[1.0,20.0,107580.0,400.0,2151600.0,1.157346e+10,8000.0,43032000.0,2.314691e+11,1.245072e+15]])
# Out:
# array([1])
