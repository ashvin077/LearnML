# %%
import pandas as pd

# %%
dataset = pd.read_excel('multiple linear regression.xlsx')
dataset.head(5)
# Out:
#    age  experience  salary
# 0   53          16   82000
# 1   39          18   66000
# 2   32          17   53000
# 3   45          14   65000
# 4   43          11   54500

# %%
dataset.shape
# Out:
# (60, 3)

# %%
dataset.isnull().sum()
# Out:
# age           0
# experience    0
# salary        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(), annot=True)
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 100.0

# %%
lr.predict(x_test)
# Out:
# array([ 82000.,  68000.,  41500.,  29500.,  46500., 102500.,  62000.,
#         34500.,  71500.,  68500.,  31500.,  60500.])
